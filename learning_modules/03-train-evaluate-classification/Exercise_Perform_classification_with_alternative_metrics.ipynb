# %% [markdown]
# # Exercise - Perform classification with alternative metrics
#
# Explore metrics and evaluation strategies; similar exercises may be repeated across modules.

# %%
# Starter imports for metrics
from sklearn.metrics import classification_report, confusion_matrix
