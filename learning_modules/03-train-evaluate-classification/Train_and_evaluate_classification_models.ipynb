# %% [markdown]
# # Train and evaluate classification models
#
# Starter notebook for the Microsoft Learn module: Train and evaluate classification models.
#
# Resources: https://learn.microsoft.com/en-us/training/modules/train-evaluate-classification-models/
