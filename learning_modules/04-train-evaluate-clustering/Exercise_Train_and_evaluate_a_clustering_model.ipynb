# %% [markdown]
# # Exercise - Train and evaluate a clustering model
#
# Starter notebook to apply clustering algorithms and evaluate results.

# %%
# Starter imports
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
