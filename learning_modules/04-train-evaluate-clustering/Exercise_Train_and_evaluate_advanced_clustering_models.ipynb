# %% [markdown]
# # Exercise - Train and evaluate advanced clustering models
#
# Explore DBSCAN, spectral clustering, and other advanced methods.

# %%
# Starter imports for advanced clustering
from sklearn.cluster import DBSCAN
