# %% [markdown]
# # Explore and analyze data with Python
#
# This notebook is a starting point for the Microsoft Learn module: Explore and analyze data with Python.
#
# Follow the module steps and add your code cells here.
#
# Resources: https://learn.microsoft.com/en-us/training/modules/explore-analyze-data-with-python/
