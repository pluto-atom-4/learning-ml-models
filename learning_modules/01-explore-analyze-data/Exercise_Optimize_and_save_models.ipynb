# %% [markdown]
# # Exercise - Optimize and save models
#
# Hyperparameter tune models and save the best estimator using joblib or pickle.

# %%
# Starter imports for model persistence and tuning
import joblib
from sklearn.model_selection import GridSearchCV
