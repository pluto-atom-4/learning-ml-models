# %% [markdown]
# # Exercise - Experiment with more powerful regression models
#
# Try models such as RandomForestRegressor, GradientBoostingRegressor, or XGBoost (if installed).

# %%
# Starter imports for advanced models
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
