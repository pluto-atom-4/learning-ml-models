# %% [markdown]
# # Exercise - Train a deep neural network
#
# Use frameworks such as TensorFlow or PyTorch to build and train a DNN.

# %%
# Starter imports (TensorFlow example)
try:
    import tensorflow as tf
except Exception:
    pass
